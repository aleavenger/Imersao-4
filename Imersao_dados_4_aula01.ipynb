# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                        Rua             Bairro     Cidade  Metragem  Quartos  \
# 9585  Rua Marcos Fernandes    Jardim da Saúde  São Paulo       115        3
# 8622    Travessa Joan Miró  Planalto Paulista  São Paulo       395        4
# 4840                   NaN    Jardim Londrina  São Paulo       268        4
# 5444                   NaN      Jardim Leonor  São Paulo       870        4
# 6667                   NaN         Campo Belo  São Paulo       210        4
# 2605          Avenida Ceci  Planalto Paulista  São Paulo       350        4
# 9620      Rua Monte Alegre           Perdizes  São Paulo       280        3
# 7999    Travessa Joan Miró  Planalto Paulista  São Paulo       390        4
# 391           Rua Honduras    Jardim Paulista  São Paulo       500        4
# 4555                   NaN     Jardim Guedala  São Paulo       833        5
#
#       Banheiros  Vagas                                  Valor
# 9585          1      5                             R$ 913.900
# 8622          6      5                           R$ 1.600.000
# 4840          5      4                           R$ 1.200.000
# 5444          6      4                           R$ 6.900.000
# 6667          4      2                           R$ 1.190.000
# 2605          4      3                           R$ 2.500.000
# 9620          5      4                           R$ 2.350.000
# 7999          6      5                           R$ 1.600.000
# 391           7      8  R$ 29.000\n                      /Mês
# 4555          7     12                           R$ 6.000.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# 120         3          5      2  R$ 2.450.000
# 155         3          4      2  R$ 1.490.000
# 160         4          5      3  R$ 2.200.000
# 334         6          4     10  R$ 1.700.000
# ...       ...        ...    ...           ...
# 9645        3          5      5  R$ 1.650.000
# 9701        3          2      4  R$ 1.650.000
# 9737        3          2      4  R$ 1.650.000
# 9807        3          1      6  R$ 1.500.000
# 9852        3          3      4  R$ 1.600.000
#
# [184 rows x 8 columns]

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(16).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados[dados.Bairro == "Planalto Paulista"].Quartos.mean()
# Out:
# 3.4564102564102566

# %% [markdown]
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)

# %%
dados.groupby("Bairro")["Metragem"].mean()
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %% [markdown]
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.query('Metragem > 500')
# Out:
#                                                   Rua               Bairro  \
# 0                               Avenida Itacira, 255     Planalto Paulista
# 18                              Rua Graham Bell, 332           Santo Amaro
# 19     Avenida Antônio Joaquim de Moura Andrade, 294   Vila Nova Conceição
# 27                             Rua Andrade Neves, 37          Bela Aliança
# 30                                   Rua dos Plátanos        Cidade Jardim
# ...                                               ...                  ...
# 9984                              Rua Alvorada do Sul       Jardim Guedala
# 9985                Rua Albertina de Oliveira Godinho       Jardim Guedala
# 9994                           Rua Circular do Bosque       Jardim Guedala
# 9995                                              NaN        Jardim Leonor
# 10004                                   Rua Guararema      Bosque da Saúde
#
#           Cidade  Metragem  Quartos  Banheiros  Vagas         Valor
# 0      São Paulo      1000        4          8      6  R$ 7.000.000
# 18     São Paulo       772        7          7      6  R$ 2.700.000
# 19     São Paulo       605        3          3      4  R$ 4.190.000
# 27     São Paulo       502        4          6      4  R$ 2.985.000
# 30     São Paulo      1195        4          4      6  R$ 8.700.000
# ...          ...       ...      ...        ...    ...           ...
# 9984   São Paulo       605        5          7      5  R$ 8.000.000
# 9985   São Paulo      1305        5          7      6  R$ 5.900.000
# 9994   São Paulo       655        5          6      4  R$ 5.000.000
# 9995   São Paulo      1350        5          9      7  R$ 9.500.000
# 10004  São Paulo       605        8          7      5  R$ 2.300.000
#
# [2088 rows x 8 columns]

# %%
planalto = dados.Bairro == 'Planalto Paulista'
planalto = dados[planalto]
planalto
# Out:
#                                 Rua             Bairro     Cidade  Metragem  \
# 0             Avenida Itacira, 255   Planalto Paulista  São Paulo      1000
# 75     Rua Francisco de Paula Brito  Planalto Paulista  São Paulo       250
# 79              Rua Elisa Rodrigues  Planalto Paulista  São Paulo       184
# 87                              NaN  Planalto Paulista  São Paulo       119
# 116          Alameda dos Guainumbis  Planalto Paulista  São Paulo       200
# ...                             ...                ...        ...       ...
# 9878                            NaN  Planalto Paulista  São Paulo       200
# 9883            Alameda dos Tupinas  Planalto Paulista  São Paulo       405
# 9930                  Avenida Odila  Planalto Paulista  São Paulo       262
# 9966                  Avenida Odila  Planalto Paulista  São Paulo       267
# 10002                 Avenida Odila  Planalto Paulista  São Paulo       267
#
#        Quartos  Banheiros  Vagas         Valor
# 0            4          8      6  R$ 7.000.000
# 75           3          4      4  R$ 2.190.000
# 79           4          3      4  R$ 1.390.000
# 87           2          2      2    R$ 670.000
# 116          4          6      3  R$ 2.014.000
# ...        ...        ...    ...           ...
# 9878         3          3      3    R$ 680.000
# 9883         4          6      4  R$ 1.550.000
# 9930         3          6      4  R$ 1.500.000
# 9966         3          6      4  R$ 1.500.000
# 10002        3          6      4  R$ 1.500.000
#
# [195 rows x 8 columns]

# %%
dados[dados.Bairro == 'Planalto Paulista']
# Out:
#                                 Rua             Bairro     Cidade  Metragem  \
# 0             Avenida Itacira, 255   Planalto Paulista  São Paulo      1000
# 75     Rua Francisco de Paula Brito  Planalto Paulista  São Paulo       250
# 79              Rua Elisa Rodrigues  Planalto Paulista  São Paulo       184
# 87                              NaN  Planalto Paulista  São Paulo       119
# 116          Alameda dos Guainumbis  Planalto Paulista  São Paulo       200
# ...                             ...                ...        ...       ...
# 9878                            NaN  Planalto Paulista  São Paulo       200
# 9883            Alameda dos Tupinas  Planalto Paulista  São Paulo       405
# 9930                  Avenida Odila  Planalto Paulista  São Paulo       262
# 9966                  Avenida Odila  Planalto Paulista  São Paulo       267
# 10002                 Avenida Odila  Planalto Paulista  São Paulo       267
#
#        Quartos  Banheiros  Vagas         Valor
# 0            4          8      6  R$ 7.000.000
# 75           3          4      4  R$ 2.190.000
# 79           4          3      4  R$ 1.390.000
# 87           2          2      2    R$ 670.000
# 116          4          6      3  R$ 2.014.000
# ...        ...        ...    ...           ...
# 9878         3          3      3    R$ 680.000
# 9883         4          6      4  R$ 1.550.000
# 9930         3          6      4  R$ 1.500.000
# 9966         3          6      4  R$ 1.500.000
# 10002        3          6      4  R$ 1.500.000
#
# [195 rows x 8 columns]

# %% [markdown]
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)

# %%
planalto.sample(15).plot()
# Out:
# <AxesSubplot:>

# %%
planalto.sample(15).plot.box()
# Out:
# <AxesSubplot:>

# %%
type(planalto)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.Banheiros.plot.area('Bairro')
# Out:
# <AxesSubplot:>

# %%
dados.groupby("Bairro")["Banheiros"].mean().plot()
# Out:
# <AxesSubplot:xlabel='Bairro'>

# %%
dados.groupby("Bairro")["Banheiros"].mean().nlargest(n=5).plot()
# Out:
# <AxesSubplot:xlabel='Bairro'>

# %% [markdown]
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)

# %%
dados.mean()
# Out:
# C:\Users\aleav\AppData\Local\Temp\ipykernel_28364\3010149702.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dados.mean()
# Metragem     442.300659
# Quartos        3.483114
# Banheiros      3.879097
# Vagas          4.097222
# dtype: float64

# %%
dados.max()
# Out:
# C:\Users\aleav\AppData\Local\Temp\ipykernel_28364\598859526.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dados.max()
# Cidade        São Paulo
# Metragem         750000
# Quartos              16
# Banheiros            40
# Vagas                50
# Valor        R$ 999.999
# dtype: object

# %%
dados.min()
# Out:
# C:\Users\aleav\AppData\Local\Temp\ipykernel_28364\3539813082.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dados.min()
# Cidade          São Paulo
# Metragem               10
# Quartos                 1
# Banheiros               1
# Vagas                   1
# Valor        R$ 1.000.000
# dtype: object

# %%
dados.median()
# Out:
# C:\Users\aleav\AppData\Local\Temp\ipykernel_28364\3136383947.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dados.median()
# Metragem     290.0
# Quartos        3.0
# Banheiros      4.0
# Vagas          4.0
# dtype: float64

# %% [markdown]
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
data = pd.read_csv(url, index_col = "Bairro")
url
data
# Out:
#                                                Rua     Cidade  Metragem  \
# Bairro
# Planalto Paulista            Avenida Itacira, 255   São Paulo      1000
# Jardim dos Estados  Rua Aurelia Perez Alvarez, 42   São Paulo       496
# Jardim Reimberg                    Rua Alba Valdez  São Paulo       125
# Jardim Morumbi                                 NaN  São Paulo       310
# Mooca                     Rua Tobias Barreto, 195   São Paulo       100
# ...                                            ...        ...       ...
# Vila Sofia                              Rua Tapuçu  São Paulo        95
# Bosque da Saúde                      Rua Guararema  São Paulo       605
# Vila da Saúde                    Rua Estero Belaco  São Paulo       205
# Vila Oratório              Rua Manuel Onha, , 514   São Paulo       185
# Vila Alpina             Rua Barão de Tramandaí, 0   São Paulo       122
#
#                     Quartos  Banheiros  Vagas  \
# Bairro
# Planalto Paulista         4          8      6
# Jardim dos Estados        4          4      4
# Jardim Reimberg           4          3      2
# Jardim Morumbi            3          2      4
# Mooca                     3          2      2
# ...                     ...        ...    ...
# Vila Sofia                2          2      2
# Bosque da Saúde           8          7      5
# Vila da Saúde             3          3      6
# Vila Oratório             3          2      2
# Vila Alpina               3          2      2
#
#                                                    Valor
# Bairro
# Planalto Paulista                           R$ 7.000.000
# Jardim dos Estados                          R$ 3.700.000
# Jardim Reimberg                               R$ 380.000
# Jardim Morumbi                                R$ 685.000
# Mooca                                         R$ 540.000
# ...                                                  ...
# Vila Sofia                                    R$ 665.000
# Bosque da Saúde                             R$ 2.300.000
# Vila da Saúde                               R$ 1.050.000
# Vila Oratório       R$ 2.200\n                      /Mês
# Vila Alpina                                   R$ 270.000
#
# [10008 rows x 7 columns]

# %%
na=data.Rua.isna()
na
# Out:
# Bairro
# Planalto Paulista     False
# Jardim dos Estados    False
# Jardim Reimberg       False
# Jardim Morumbi         True
# Mooca                 False
#                       ...
# Vila Sofia            False
# Bosque da Saúde       False
# Vila da Saúde         False
# Vila Oratório         False
# Vila Alpina           False
# Name: Rua, Length: 10008, dtype: bool

# %%
nad = data[na]
nad
nadplus = nad.Rua.isna().sum()
nadplus
# Out:
# 3434

# %% [markdown]
# Aula 2

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados["Valor"].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[["Rua","Valor"]]
# Out:
#                                   Rua                                 Valor
# 0               Avenida Itacira, 255                           R$ 7.000.000
# 1      Rua Aurelia Perez Alvarez, 42                           R$ 3.700.000
# 2                     Rua Alba Valdez                            R$ 380.000
# 3                                 NaN                            R$ 685.000
# 4            Rua Tobias Barreto, 195                             R$ 540.000
# ...                               ...                                   ...
# 10003                      Rua Tapuçu                            R$ 665.000
# 10004                   Rua Guararema                          R$ 2.300.000
# 10005               Rua Estero Belaco                          R$ 1.050.000
# 10006         Rua Manuel Onha, , 514   R$ 2.200\n                      /Mês
# 10007      Rua Barão de Tramandaí, 0                             R$ 270.000
#
# [10008 rows x 2 columns]

# %%
dados2 = dados.copy()
dados2
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# 2           125        4          3      2
# 3           310        3          2      4
# 4           100        3          2      2
# ...         ...      ...        ...    ...
# 10003        95        2          2      2
# 10004       605        8          7      5
# 10005       205        3          3      6
# 10006       185        3          2      2
# 10007       122        3          2      2
#
#                                       Valor
# 0                              R$ 7.000.000
# 1                              R$ 3.700.000
# 2                                R$ 380.000
# 3                                R$ 685.000
# 4                                R$ 540.000
# ...                                     ...
# 10003                            R$ 665.000
# 10004                          R$ 2.300.000
# 10005                          R$ 1.050.000
# 10006  R$ 2.200\n                      /Mês
# 10007                            R$ 270.000
#
# [10008 rows x 8 columns]

# %%
dados2
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# 2           125        4          3      2
# 3           310        3          2      4
# 4           100        3          2      2
# ...         ...      ...        ...    ...
# 10003        95        2          2      2
# 10004       605        8          7      5
# 10005       205        3          3      6
# 10006       185        3          2      2
# 10007       122        3          2      2
#
#                                       Valor
# 0                              R$ 7.000.000
# 1                              R$ 3.700.000
# 2                                R$ 380.000
# 3                                R$ 685.000
# 4                                R$ 540.000
# ...                                     ...
# 10003                            R$ 665.000
# 10004                          R$ 2.300.000
# 10005                          R$ 1.050.000
# 10006  R$ 2.200\n                      /Mês
# 10007                            R$ 270.000
#
# [10008 rows x 8 columns]

# %%
dados2["Valor"].str.split(expand = True)
dados2[["Currency","Value","Type"]] = dados2["Valor"].str.split(expand = True)
dados2
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# 2           125        4          3      2
# 3           310        3          2      4
# 4           100        3          2      2
# ...         ...      ...        ...    ...
# 10003        95        2          2      2
# 10004       605        8          7      5
# 10005       205        3          3      6
# 10006       185        3          2      2
# 10007       122        3          2      2
#
#                                       Valor Currency      Value  Type
# 0                              R$ 7.000.000       R$  7.000.000  None
# 1                              R$ 3.700.000       R$  3.700.000  None
# 2                                R$ 380.000       R$    380.000  None
# 3                                R$ 685.000       R$    685.000  None
# 4                                R$ 540.000       R$    540.000  None
# ...                                     ...      ...        ...   ...
# 10003                            R$ 665.000       R$    665.000  None
# 10004                          R$ 2.300.000       R$  2.300.000  None
# 10005                          R$ 1.050.000       R$  1.050.000  None
# 10006  R$ 2.200\n                      /Mês       R$      2.200  /Mês
# 10007                            R$ 270.000       R$    270.000  None
#
# [10008 rows x 11 columns]

# %%
# dados2['Type'] = dados2.Valor
# dados2
